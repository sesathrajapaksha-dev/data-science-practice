# %%
import numpy as np
import time

n=1_000_000

a=np.arange(n)

start = time.time()
result_loop=[]
for x in a:
    result_loop.append(x*2)
end = time.time()

print(f'duration : {end - start}')


start = time.time()
result_vectorized = a*2
end = time.time()
print(f'New duration {end - start}')
# Out:
# duration : 13.301942825317383
# New duration 0.0006108283996582031
