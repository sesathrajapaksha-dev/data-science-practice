# %%
import pandas as pd 
df=pd.read_csv('Data/cwurData.csv')
print(df.index)
print(df[['institution','world_rank']].head(5))
print("\n-------------------------------------------------------------------------")
df_indexed=df.set_index('world_rank')
print('After setting index : \n')
print(df_indexed['institution'].head(5))
print("\n-------------------------------------------------------------------------")

df_reset=df_indexed.reset_index()
print("After resetting : \n")
print(df_reset.head(5))
# Out:
# RangeIndex(start=0, stop=2200, step=1)
#                              institution  world_rank
# 0                     Harvard University           1
# 1  Massachusetts Institute of Technology           2
# 2                    Stanford University           3
# 3                University of Cambridge           4
# 4     California Institute of Technology           5
#
# -------------------------------------------------------------------------
# After setting index :
#
# world_rank
# 1                       Harvard University
# 2    Massachusetts Institute of Technology
# 3                      Stanford University
# 4                  University of Cambridge
# 5       California Institute of Technology
# Name: institution, dtype: str
#
# -------------------------------------------------------------------------
# After resetting :
#
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# ...
