# %% [markdown]
# Tuples — like lists, but immutable (can't be changed after creation)

# %%
point = (3, 4)
x, y = point          # unpacking
point[0]               # 3
point[0] = 10           # ERROR — tuples can't be modified
